# %%
import numpy as np 
import pandas as pd

# %%
file1_path = ''
file2_path = ''

# %%
df1 = pd.read_csv(file1_path)
df2 = pd.read_csv(file2_path)

# %%
df1.x = (df1.x + df2.x) / 2.
df1.y = (df1.y + df2.y) / 2.

# %%
df1.to_csv('final.csv', index=False)
